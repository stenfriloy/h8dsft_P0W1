# %% [markdown]
# # Graded Challenges 1

# %% [markdown]
# # 1 Perkenalan

# %%
# menunjukkan data yang ingin diolah
# tujuannya adalah melihat nilai HP yang paling tinggi dengan melihat perbandingan type 1 dan type 2

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('C:/HACKTIV8/Week 1/Graded Challenges/Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True

# %%
# mengisi data yang kosong

df['Type 2'].fillna(
    value = 'New Type', inplace = True)

# %%
df
# Out:
#                       Name   Type 1    Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass    Poison    318  45      49       49
# 1                  Ivysaur    Grass    Poison    405  60      62       63
# 2                 Venusaur    Grass    Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass    Poison    625  80     100      123
# 4               Charmander     Fire  New Type    309  39      52       43
# ..                     ...      ...       ...    ...  ..     ...      ...
# 795                Diancie     Rock     Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock     Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic     Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic      Dark    680  80     160       60
# 799              Volcanion     Fire     Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Ratio
# ...

# %%
# Querying data

data_baru = df[df['Type 2']=='New Type']
data_baru
# Out:
#            Name  Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 4    Charmander    Fire  New Type    309   39      52       43       60
# 5    Charmeleon    Fire  New Type    405   58      64       58       80
# 9      Squirtle   Water  New Type    314   44      48       65       50
# 10    Wartortle   Water  New Type    405   59      63       80       65
# 11    Blastoise   Water  New Type    530   79      83      100       85
# ..          ...     ...       ...    ...  ...     ...      ...      ...
# 775     Sliggoo  Dragon  New Type    452   68      75       53       83
# 776      Goodra  Dragon  New Type    600   90     100       70      110
# 788    Bergmite     Ice  New Type    304   55      69       85       32
# 789     Avalugg     Ice  New Type    514   95     117      184       44
# 792     Xerneas   Fairy  New Type    680  126     131       95      131
#
#      Sp. Def  Speed  Generation  Legendary     Ratio
# ...

# %%
df.shape
# Out:
# (800, 13)

# %%
del df['#'] # menghapus kolom yang kurang penting
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '#'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-1f75707a268b> in <module>
# ...

# %%
df['Ratio'] = df['Attack']/df['Defense'] # melihat rasio kekuatan jenis pokemon

df
# Out:
#                       Name   Type 1    Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass    Poison    318  45      49       49
# 1                  Ivysaur    Grass    Poison    405  60      62       63
# 2                 Venusaur    Grass    Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass    Poison    625  80     100      123
# 4               Charmander     Fire  New Type    309  39      52       43
# ..                     ...      ...       ...    ...  ..     ...      ...
# 795                Diancie     Rock     Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock     Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic     Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic      Dark    680  80     160       60
# 799              Volcanion     Fire     Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Ratio
# ...

# %% [markdown]
# # Eksplorasi

# %%
# grouping

grup = df.groupby('Type 2', sort=False)['HP'].sum()
grup
# Out:
# Type 2
# Poison       1998
# New Type    26158
# Flying       6925
# Dragon       1479
# Ground       2703
# Fairy        1479
# Grass        1566
# Fighting     2066
# Psychic      2383
# Steel        1422
# Ice          1260
# Rock          953
# Dark         1511
# Water         878
# Electric      529
# Fire          855
# Ghost         828
# Bug           160
# Normal        254
# Name: HP, dtype: int64

# %%
df[
    (df['Type 2']== 'New Type')
].groupby(['Total', 'Speed'])['Ratio'].sum()
# Out:
# Total  Speed
# 180    30       1.000000
# 194    25       0.609756
# 195    20       1.285714
#        45       0.857143
# 200    35       0.875000
#                   ...
# 680    99       1.378947
#        130      1.222222
# 720    120      1.000000
# 770    90       1.666667
# 780    140      2.142857
# Name: Ratio, Length: 337, dtype: float64

# %%
# %matplotlib inline

# %%
df[df['Type 2']=='Poison'].groupby('Type 1')['HP'].sum().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Type 1'>

# %% [markdown]
# # Kesimpulan

# %%
# kesimpulan yang didapat adalah pada tipe 2 (Poison), ternyata yang memiliki nilai HP tertinggi adalah type 1 Grass.
